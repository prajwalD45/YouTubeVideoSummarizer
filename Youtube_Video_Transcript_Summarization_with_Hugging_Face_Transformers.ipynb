# %%
# !pip install -q transformers

# %%
# !pip install -q youtube_transcript_api

# %%
from transformers import pipeline
from youtube_transcript_api import YouTubeTranscriptApi

# %%
youtube_video = "https://www.youtube.com/watch?v=Z_f9Rn69PdM"

# %%
video_id = youtube_video.split("=")[1]

# %%
video_id
# Out:
# 'FMqzm_kvpIw'

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_id)

# %%
YouTubeTranscriptApi.get_transcript(video_id)
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript[0:5]
# Out:
# [{'text': "today we're going to take a look at the",
#   'start': 0.0,
#   'duration': 3.959},
#  {'text': 'best tools for website building in 30',
#   'start': 2.04,
#   'duration': 4.799},
#  {'text': 'seconds using AI without the needs of',
#   'start': 3.959,
#   'duration': 5.1},
#  {'text': 'coding or manual designing all the tools',
#   'start': 6.839,
#   'duration': 3.601},
#  {'text': "that I'm going to mention in this video",
#   'start': 9.059,
#   'duration': 3.54}]

# %%
result = ""
for i in transcript:
    result += ' ' + i['text']
#print(result)
print(len(result))
# Out:
# 6558

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
num_iters = int(len(result)/1000)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + result[start:end])
  out = summarizer(result[start:end])
  out = out[0]
  out = out['summary_text']
  print("Summarized text\n"+out)
  summarized_text.append(out)

#print(summarized_text)
# Out:
# input text
# ...

# %%
len(str(summarized_text))
# Out:
# 2519

# %%
str(summarized_text)
# Out:
# '[\' Wix ADI is an AI powered tool offered by Wix a popular website builder that helps users create personalized websites quickly and easily to start off click on the link in the description below that will direct you to wix.com and then select get started this will guide you through a few questions about the vision of your site and your experience level . It will then prompt you with two options to build the site yourself with the old Wix editor which requires some time and effort .\', \' Wix ADI will request for personalized details such as the name of your website social media accounts as well as any specific images text or logos that you wish to include . The tool will also offer various options for other web pages that are designed to meet your business needs .\', " durable durable is a fantastic tool for building websites using the power of AI technology on their website that you can find in the description as well they claim that they\'re the world\'s fastest AI website builde
# ...

# %%
# !pip install deep-translator
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from deep_translator import GoogleTranslator
print("Summary In Marathi")
for para in summarized_text:

  for text in para.split("."):

    translated = GoogleTranslator(source='auto', target='mr').translate(text) 
    print(translated)
# Out:
# Summary In marathi
# Wix ADI हे Wix या लोकप्रिय वेबसाइट बिल्डरने ऑफर केलेले AI समर्थित साधन आहे जे वापरकर्त्यांना वैयक्तिकृत वेबसाइट जलद आणि सहजपणे तयार करण्यास मदत करते आणि खाली दिलेल्या वर्णनातील लिंकवर क्लिक करा जे तुम्हाला wix वर निर्देशित करेल.
# com आणि नंतर प्रारंभ करा निवडा हे आपल्या साइटच्या दृष्टी आणि आपल्या अनुभवाच्या पातळीबद्दल काही प्रश्नांबद्दल मार्गदर्शन करेल
# त्यानंतर ते तुम्हाला जुन्या Wix संपादकासह स्वतः साइट तयार करण्यासाठी दोन पर्यायांसह सूचित करेल ज्यासाठी थोडा वेळ आणि मेहनत आवश्यक आहे.
#
# Wix ADI वैयक्तिकृत तपशिलांसाठी विनंती करेल जसे की तुमच्या वेबसाइटचे सोशल मीडिया खात्यांचे नाव तसेच तुम्ही समाविष्ट करू इच्छित असलेल्या कोणत्याही विशिष्ट प्रतिमा मजकूर किंवा लोगो
# हे टूल तुमच्या व्यावसायिक गरजा पूर्ण करण्यासाठी डिझाइन केलेल्या इतर वेब पेजेससाठी विविध पर्याय देखील ऑफर करेल
#
# ...

# %%
from deep_translator import GoogleTranslator
print("Summary In Hindi")
for para in summarized_text:

  for text in para.split("."):

    translated = GoogleTranslator(source='auto', target='hi').translate(text) 
    print(translated)
# Out:
# Summary In Hindi
# Wix ADI, Wix द्वारा पेश किया गया एक AI पावर्ड टूल है, जो एक लोकप्रिय वेबसाइट बिल्डर है, जो उपयोगकर्ताओं को जल्दी और आसानी से वैयक्तिकृत वेबसाइट बनाने में मदद करता है, नीचे दिए गए विवरण में दिए गए लिंक पर क्लिक करें जो आपको Wix की ओर निर्देशित करेगा।
# कॉम पर क्लिक करें और फिर आरंभ करें चुनें यह आपकी साइट के विज़न और आपके अनुभव के स्तर के बारे में कुछ प्रश्नों के माध्यम से आपका मार्गदर्शन करेगा
# इसके बाद यह आपको पुराने Wix संपादक के साथ स्वयं साइट बनाने के दो विकल्पों के साथ संकेत देगा जिसके लिए कुछ समय और प्रयास की आवश्यकता होती है
#
# Wix ADI वैयक्तिकृत विवरणों के लिए अनुरोध करेगा जैसे कि आपकी वेबसाइट का नाम सोशल मीडिया खातों के साथ-साथ कोई विशिष्ट चित्र पाठ या लोगो जिसे आप शामिल करना चाहते हैं
# टूल अन्य वेब पेजों के लिए विभिन्न विकल्प भी प्रदान करेगा जो आपकी व्यावसायिक आवश्यकताओं को पूरा करने के लिए डिज़ाइन किए गए हैं
#
# ...
